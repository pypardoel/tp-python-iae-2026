# %% [markdown]
# # 📋TP Python - Aide mémoire
# ---
#
# ## ⚙️ Python

# %%
# comprendre str()
print(2+2)
print("2+2")
print("2" + "2")
#str() permet de convertir un nombre entier en une chaîne de caractères
print(str(2) + str(2))
# Out:
# 4
# 2+2
# 22
# 22

# %%
# fonction sum()
# affiche le total des valeurs d'une liste
sum( [120, 340, 275, 410])
# Out:
# 1145

# %%
# fonction len()
pays_clients = ["France", "Allemagne", "Canada", "Japon"]
# affiche la taille de la liste
len(pays_clients)
# Out:
# 4
