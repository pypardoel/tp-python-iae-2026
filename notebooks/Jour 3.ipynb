# %% [markdown]
# # 📋TP Python - Révisions
# ---
# ## 🗓 Programme
# - 25/03/2025 - Prise en main de Python
# - 02/04/2025 - Cas pratique d'analyse de données
# - **03/04/2025 - Révisions et Evaluation**
#
#
#
# ## 🎯 Objectifs des révisions
# - Explorer les données
# - Filtrer les données
# - Analyser les données
# - Visualiser les données
#
# Manipulation des données avec Pandas :
# https://pandas.pydata.org/docs/user_guide/index.html
#
# Représentation des données avec Plotly :
# https://plotly.com/python/
#
# A partir de ce dataset

# %% [markdown]
# ## 1️⃣ Mise en place

# %%
import pandas as pd
import plotly.express as px

data = [
    ["2025-01-10","Usine Alpha","NutriPet","France","Camion",1200,450],
    ["2025-01-12","Usine Beta","AquaFeed","Espagne","Camion",900,800],
    ["2025-01-15","Usine Alpha","GreenFarm","Allemagne","Rail",1500,900],
    ["2025-01-18","Usine Gamma","NutriPet","Italie","Bateau",3000,1500],
    ["2025-01-20","Usine Beta","BioFeed","Belgique","Camion",700,300],
    ["2025-01-22","Usine Gamma","AquaFeed","Pays-Bas","Rail",1100,650],
    ["2025-01-25","Usine Alpha","BioFeed","France","Camion",800,200],
    ["2025-01-28","Usine Beta","GreenFarm","Allemagne","Rail",1400,950]
]

df = pd.DataFrame(data, columns=[
    "date","usine","client","pays","transport","quantite_kg","distance_km"
])

df["date"] = pd.to_datetime(df["date"])
df
# Out:
#         date        usine     client       pays transport  quantite_kg  \
# 0 2025-01-10  Usine Alpha   NutriPet     France    Camion         1200
# 1 2025-01-12   Usine Beta   AquaFeed    Espagne    Camion          900
# 2 2025-01-15  Usine Alpha  GreenFarm  Allemagne      Rail         1500
# 3 2025-01-18  Usine Gamma   NutriPet     Italie    Bateau         3000
# 4 2025-01-20   Usine Beta    BioFeed   Belgique    Camion          700
# 5 2025-01-22  Usine Gamma   AquaFeed   Pays-Bas      Rail         1100
# 6 2025-01-25  Usine Alpha    BioFeed     France    Camion          800
# 7 2025-01-28   Usine Beta  GreenFarm  Allemagne      Rail         1400
#
#    distance_km
# 0          450
# 1          800
# 2          900
# 3         1500
# 4          300
# 5          650
# 6          200
# 7          950

# %% [markdown]
# ## 2️⃣ Exercices Pandas
# ### Exercice 1 — Exploration
#
# *Questions :*
#
# 1️⃣ Combien de lignes contient le dataset ?
# 2️⃣ Quelle est la quantité moyenne expédiée ?
# 3️⃣ Quelle est la distance maximale ?

# %% [markdown]
# ### Exercice 2 — Filtrage
#
# *Questions :*
#
# 1️⃣ Afficher uniquement les livraisons en camion
# 2️⃣ Afficher les livraisons supérieures à 1000 kg

# %% [markdown]
# ## Exercice 3 — Agrégation
#
# *Questions :*
#
# 1️⃣ Quantité totale expédiée par client

# %% [markdown]
# 2️⃣ Quantité totale par mode de transport

# %% [markdown]
# 3️⃣ Distance moyenne par usine

# %% [markdown]
# ## Exercice 4 — Nouvelle variable
#
# Entonova estime les coûts logistiques :
#
# Transport : coût €/kg/km :
# - Camion : 0.002
# - Rail : 0.0012
# - Bateau : 0.0008
#
# Créer une colonne ```coût_total```
# en créant d'abord un dictionnaire nommé ```cout``` décrivant les données du dessus puis en utilisant faisant le calcul en utilisant map() sur la Série ```transport``` avec le dictionnaire  ```cout``` :
# https://pandas.pydata.org/docs/reference/api/pandas.Series.map.html#pandas.Series.map

# %% [markdown]
# # 3️⃣ Visualisation Plotly

# %%
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *
import plotly.express as px

init_notebook_mode(connected=True)         # permet d'afficher le résultat dans le notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %% [markdown]
# ## Graphique 1 — Quantité par client
# Avec px.bar afficher la quantitée livrée par client

# %% [markdown]
# ## Graphique 2 — Répartition par transport
# Avec px.pie afficher la répartition des livraisons par transport

# %% [markdown]
# ## Graphique 3 — Distance vs Quantité
# avec px.scatter afficher une analyse des livraisons : avec en x la distance, en y la quantité et un mode de transport par couleur. La taille du point correspond à la quantité transportée

# %% [markdown]
# ## Graphique 4 — Coût logistique total par client
# avec px.bar afficher le coût total du transport par client
