# %% [markdown]
# # 📋TP Python - Evaluation
# ---
# ## 🗓 Programme
# - 25/03/2025 - Prise en main de Python
# - 02/04/2025 - Cas pratique d'analyse de données
# - **03/04/2025 - Révisions et Evaluation**
#
#
#
# ## 🎯 Objectifs de l'évaluation :
# - Charger des données
# - Explorer les données
# - Analyser la production
# - Analyser la logistique
# - Visualiser les données
#
# ## 🎓 Evaluation :
# Renseigner le Google Form accessible ici :
# https://forms.gle/Zq6vNJiJhSeCNRiv9
#
# Manipulation des données avec Pandas :
# https://pandas.pydata.org/docs/user_guide/index.html
#
# Représentation des données avec Plotly :
# https://plotly.com/python/

# %% [markdown]
# ## 🟢 Partie 1 — Chargement des données (15 min)
# ### Question 1 - importer la bibliothèque pandas
# 👉 Réponse à coller : la ligne de code utilisée pour l'import

# %% [markdown]
# ### Question 2 - charger le fichier
# charger le fichier ../data/entonova_production.csv dans une variable df_production
# 👉 Réponse à coller : la ligne de code utilisée pour le chargement

# %% [markdown]
# ### Question 3 - afficher un extrait du fichier
# Afficher les 5 premières lignes du DataFrame
# 👉 Réponse à coller : la ligne de code utilisée pour l'affichage

# %% [markdown]
# ### Question 4 - volume des données
# Combien de lignes et colonnes constituent les données ?
# 👉 Réponse à coller : le résultat de la commande

# %% [markdown]
# ## 🟢 Partie 2 — Exploration des données (15 min)
# ### Question 5 - nombre d'usines
# Combien y'a-t-il d'usines différentes ?
# 👉 Réponse à coller : le résultat de la commande

# %% [markdown]
# ### Question 6 - types de produits
# Quel est le nom des différents produits fabriqués ?
# 👉 Réponse à coller : le résultat de la commande

# %% [markdown]
# ### Question 7 - types de produits
# Quel est le stock moyen ?
# 👉 Réponse à coller : le résultat de la commande

# %% [markdown]
# ## 🟢 Partie 3 — Analyse de la production (25 min)
# ### Question 8 - production totale
# Quelle est la production totale (quantité) sur toute la période ?
# 👉 Réponse à coller : le résultat de la commande

# %% [markdown]
# ### Question 9 - production des usines
# Quelle usine produit le plus de volume ? (Lister la production totale de chaque usine)
# 👉 Réponse à coller : le nom de l'usine avec la quantité produite

# %% [markdown]
# ### Question 10 - production moyenne par produit
# Quelle est la production moyenne par produit ?
# 👉 Réponse à coller : le tableau avec les données

# %% [markdown]
# ## 🟢 Partie 4 — Analyse de la logistique (35 min)
# chargement du fichier ../data/entonova_expedition.csv dans une variable df_expedition et affichage des 5 premières lignes

# %%
df_expedition = pd.read_csv('../data/entonova_expedition.csv',parse_dates=True)
#conversion en fomat date pour exploitation
df_expedition["date"] = pd.to_datetime(df_expedition["date"])

df_expedition.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_expedition = pd.read_csv('../data/entonova_expedition.csv',parse_dates=True)
#       2 #conversion en fomat date pour exploitation
#       3 df_expedition["date"] = pd.to_datetime(df_expedition["date"])
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Question 11 - quel plus gros client
# Quel client reçoit le plus de marchandise
# 👉 Réponse à coller : la ligne du plus gros client avec la quantité associée

# %% [markdown]
# ### Question 12 - coût moyen du transport
# Quel est le coût moyen du transport ?
# 👉 Réponse à coller : le résultat de la commande

# %% [markdown]
# ### Question 13 - coût du transport / quantité
# Créer une nouvelle colonne ```coût_par_quantité``` construite à partir des colonnes ```coût_transport``` et ```quantité```
# 👉 Réponse à coller : la ligne de code permettant d'ajouter la colonne

# %% [markdown]
# ### Question 14 - coût logistique moyen par kg le plus élevé
# Quel client a le coût logistique moyen par quantité le plus élevé ?
# 👉 Réponse à coller : la ligne avec le nom du client et le coût du transport / quantité

# %% [markdown]
# ### Question 15 - Ajouter une colonne année
# Créer une nouvelle colonne ```année``` construite à partir de la colonne ```date```.
# 👉 Réponse à coller : la ligne de code permettant d'ajouter la colonne

# %% [markdown]
# ## 🟢 Partie 5 — Visualisation Plotly (30 min)
# Import des libraires nécessaires à l'utilisation des graphiques

# %%
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *
import plotly.express as px

init_notebook_mode(connected=True)         # permet d'afficher le résultat dans le notebook

# %% [markdown]
# ### Question 16 - Carte des expéditions
# Créer une carte mondiale des quantités totales expédiées par client et par type de produit en 2028 avec Plotly.
#
# Utiliser ce type de graphique : https://plotly.com/python/bubble-maps/
#
# 👉 Réponse à coller : En passant la souris , donner la valeur de quantité correspondant au client situé à proximité de Genève en Suisse

# %% [markdown]
# ### Question 17 - Production annuelle des usines
# Créer un graphique en colonnes de type "Bar Charts with Text" en affichant les quantités totales produites par usine et par type de produit
#
# Utiliser ce type de graphique : https://plotly.com/python/bar-charts/#bar-charts-with-text et aller dans le paragraphe "Bar Charts with Text"
#
# - en x -> usines
# - en y -> quantités produites
# - en détail de chaque colonnes la répartition des produits
#
# 👉 Réponse à coller : En passant la souris , donner le volume de la plus petite production de l'usine Espagnole

# %% [markdown]
# ### Question 18 - Evolution du coût du transport
# Créer un graphique avec des courbes représentant le coût de transport moyen par quantité, par type de transport et par an
# Utiliser ce type de graphique : https://plotly.com/python/line-charts/#line-plots-with-column-encoding-color
# - en x -> années
# - en y -> coût de transport moyen
# - la couleur associée à chaque type de moyen de transport
#
# 👉 Réponse à coller : En passant la souris , donner le cout par quantité du transport par bateau en 2026

# %% [markdown]
# ## Evaluation du TP
#
# Merci de laisser un avis sur ce formulaire :
# https://forms.gle/GesBVXvjTvW8CpSV7
